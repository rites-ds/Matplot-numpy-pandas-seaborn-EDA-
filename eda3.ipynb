# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv('Good_Reads_Book_Awards_Crawl_2023_12_27_11_14.csv')
df.sample(5)
# Out:
#                                             source_URL  Readers Choice Votes  \
# 206  https://www.goodreads.com/book/show/60784312-a...                 19745
# 102  https://www.goodreads.com/book/show/60766189-a...                 39708
# 213  https://www.goodreads.com/book/show/59948520-i...                  5303
# 126  https://www.goodreads.com/book/show/60468332-t...                 18660
# 249  https://www.goodreads.com/book/show/88564046-t...                  4034
#
#     Readers Choice Category                         Title  \
# 206             Debut Novel                      Adelaide
# 102                 Fantasy         A Day of Fallen Night
# 213             Debut Novel                   In Memoriam
# 126         Science Fiction              The Light Pirate
# 249  Memoir & Autobiography  Thicker than Water: A Memoir
#
#                   Author  Total Avg Rating Number of Ratings  \
# 206    Genevieve Wheeler              3.99            23,881
# 102  Samantha    Shannon              4.41            22,295
# 213           Alice Winn              4.56            11,386
# 126   Lily Brooks-Dalton              4.06            23,184
# 249     Kerry Washington              3.92             6,981
#
#     Number of Reviews  Number of Pages    Edition  \
# 206             4,071              304  Hardcover
# 102             4,064              868  Hardcover
# 213             2,156              382  Hardcover
# 126             3,656              336  Hardcover
# 249               718              320  Hardcover
#
#                                       Book Description First Published date  \
# 206  For twenty-six-year-old Adelaide Williams, an ...            18-Apr-23
# 102  In A Day of Fallen Night, Samantha Shannon swe...            28-Feb-23
# 213  A haunting, virtuosic debut novel about two yo...             7-Mar-23
# 126  Florida is slipping away. As devastating weath...             6-Dec-22
# 249  Award-winning actor, director, producer, and a...            26-Sep-23
#
#     Kindle Version and Price  Kindle Price  \
# 206   Kindle Unlimited $0.00          0.00
# 102            Kindle $14.46         14.46
# 213            Kindle $14.99         14.99
# 126            Kindle $13.99         13.99
# 249            Kindle $14.99         14.99
#
#                                       About the Author
# 206  Genevieve Wheeler (that’s me!) is an American ...
# 102  Samantha Shannon studied English Language and ...
# 213  Librarian Note: There is more than one author ...
# 126  Lily Brooks-Dalton's most recent novel is The ...
# 249                                                NaN

# %%
df.head(2)
# Out:
#                                           source_URL  Readers Choice Votes  \
# 0  https://www.goodreads.com/book/show/62047984-y...                200722
# 1  https://www.goodreads.com/book/show/61771675-h...                 60171
#
#   Readers Choice Category            Title          Author  Total Avg Rating  \
# 0                 Fiction       Yellowface      R.F. Kuang              3.87
# 1                 Fiction  Hello Beautiful  Ann Napolitano              4.20
#
#   Number of Ratings Number of Reviews  Number of Pages         Edition  \
# 0           252,189            37,032              336       Hardcover
# 1           200,304            19,288              416  Kindle Edition
#
#                                     Book Description First Published date  \
# 0  Athena Liu is a literary darling and June Hayw...            25-May-23
# 1  An emotionally layered and engrossing story of...            14-Mar-23
#
#   Kindle Version and Price  Kindle Price  \
# 0            Kindle $14.99         14.99
# 1             Kindle $2.99          2.99
#
#                                     About the Author
# 0  Rebecca F. Kuang is a Marshall Scholar, transl...
# 1  Ann Napolitano’s new novel, Hello Beautiful, h...

# %%
df = df.drop(['source_URL','Book Description','About the Author'],axis=1)
df.head()
# Out:
#    Readers Choice Votes Readers Choice Category                  Title  \
# 0                200722                 Fiction             Yellowface
# 1                 60171                 Fiction        Hello Beautiful
# 2                 57702                 Fiction       The Wishing Game
# 3                 53470                 Fiction               Tom Lake
# 4                 45859                 Fiction  The Five-Star Weekend
#
#              Author  Total Avg Rating Number of Ratings Number of Reviews  \
# 0        R.F. Kuang              3.87           252,189            37,032
# 1    Ann Napolitano              4.20           200,304            19,288
# 2       Meg Shaffer              4.19            62,142            10,594
# 3      Ann Patchett              4.13           127,318            16,108
# 4  Elin Hilderbrand              4.11           116,619             8,141
#
#    Number of Pages         Edition First Published date  \
# 0              336       Hardcover            25-May-23
# 1              416  Kindle Edition            14-Mar-23
# 2              304       Hardcover            30-May-23
# 3              309       Hardcover             1-Aug-23
# 4              384       Hardcover            13-Jun-23
#
#   Kindle Version and Price  Kindle Price
# 0            Kindle $14.99         14.99
# 1             Kindle $2.99          2.99
# 2             Kindle $2.99          2.99
# 3            Kindle $15.99         15.99
# 4            Kindle $14.99         14.99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Readers Choice Votes      299 non-null    int64
#  1   Readers Choice Category   299 non-null    object
#  2   Title                     299 non-null    object
#  3   Author                    299 non-null    object
#  4   Total Avg Rating          299 non-null    float64
#  5   Number of Ratings         299 non-null    object
#  6   Number of Reviews         299 non-null    object
#  7   Number of Pages           299 non-null    int64
#  8   Edition                   299 non-null    object
#  9   First Published date      299 non-null    object
#  10  Kindle Version and Price  299 non-null    object
#  11  Kindle Price              299 non-null    float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 28.2+ KB

# %%
df.shape
# Out:
# (299, 12)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Readers Choice Votes Readers Choice Category  \
# 0                  200722                 Fiction
# 1                   60171                 Fiction
# 2                   57702                 Fiction
# 3                   53470                 Fiction
# 4                   45859                 Fiction
# ..                    ...                     ...
# 294                  2533                   Humor
# 295                  2257                   Humor
# 296                  1866                   Humor
# 297                  1137                   Humor
# 298                  1072                   Humor
#
#                                                  Title            Author  \
# 0                                           Yellowface        R.F. Kuang
# 1                                      Hello Beautiful    Ann Napolitano
# 2                                     The Wishing Game       Meg Shaffer
# 3                                             Tom Lake      Ann Patchett
# 4                                The Five-Star Weekend  Elin Hilderbrand
# ..                                                 ...               ...
# 294             Misfit: Growing Up Awkward in the '80s       Gary Gulman
# 295  Unreliable Narrator: Me, Myself, and Impostor ...  Aparna Nancherla
# 296  America the Beautiful?: One Woman in a Borrowe...   Blythe Roberson
# 297  Alexandra Petri's US History: Important Americ...   Alexandra Petri
# 298  Not Funny: Essays on Life, Comedy, Culture, Et...     Jena Friedman
#
#      Total Avg Rating Number of Ratings Number of Reviews  Number of Pages  \
# 0                3.87           252,189            37,032              336
# 1                4.20           200,304            19,288              416
# 2                4.19            62,142            10,594              304
# 3                4.13           127,318            16,108              309
# 4                4.11           116,619             8,141              384
# ..                ...               ...               ...              ...
# 294              4.23               981               155              304
# 295              3.71               517                71              304
# 296              3.83             1,200               247              304
# 297              3.72               600               164              326
# 298              3.76               658               120              256
#
#             Edition First Published date Kindle Version and Price  \
# 0         Hardcover            25-May-23            Kindle $14.99
# 1    Kindle Edition            14-Mar-23             Kindle $2.99
# 2         Hardcover            30-May-23             Kindle $2.99
# 3         Hardcover             1-Aug-23            Kindle $15.99
# 4         Hardcover            13-Jun-23            Kindle $14.99
# ..              ...                  ...                      ...
# 294       Hardcover            19-Sep-23            Kindle $14.99
# 295       Hardcover            19-Sep-23            Kindle $14.99
# 296       Paperback            18-Apr-23             Kindle $9.99
# 297       Hardcover            11-Apr-23            Kindle $14.43
# 298       Hardcover            18-Apr-23            Kindle $14.99
#
#      Kindle Price
# 0           14.99
# 1            2.99
# 2            2.99
# 3           15.99
# 4           14.99
# ..            ...
# 294         14.99
# 295         14.99
# 296          9.99
# 297         14.43
# 298         14.99
#
# [299 rows x 12 columns]>

# %%
#removing the comma in no. of reviews and no. of rating
num_col =['Number of Ratings','Number of Reviews']
for column in num_col :
    df[column] = df[column].replace(',','',regex=True)
df.head(3)
df.info
# Out:
# <bound method DataFrame.info of      Readers Choice Votes Readers Choice Category  \
# 0                  200722                 Fiction
# 1                   60171                 Fiction
# 2                   57702                 Fiction
# 3                   53470                 Fiction
# 4                   45859                 Fiction
# ..                    ...                     ...
# 294                  2533                   Humor
# 295                  2257                   Humor
# 296                  1866                   Humor
# 297                  1137                   Humor
# 298                  1072                   Humor
#
#                                                  Title            Author  \
# 0                                           Yellowface        R.F. Kuang
# 1                                      Hello Beautiful    Ann Napolitano
# 2                                     The Wishing Game       Meg Shaffer
# 3                                             Tom Lake      Ann Patchett
# 4                                The Five-Star Weekend  Elin Hilderbrand
# ..                                                 ...               ...
# 294             Misfit: Growing Up Awkward in the '80s       Gary Gulman
# 295  Unreliable Narrator: Me, Myself, and Impostor ...  Aparna Nancherla
# 296  America the Beautiful?: One Woman in a Borrowe...   Blythe Roberson
# 297  Alexandra Petri's US History: Important Americ...   Alexandra Petri
# 298  Not Funny: Essays on Life, Comedy, Culture, Et...     Jena Friedman
#
#      Total Avg Rating Number of Ratings Number of Reviews  Number of Pages  \
# 0                3.87            252189             37032              336
# 1                4.20            200304             19288              416
# 2                4.19             62142             10594              304
# 3                4.13            127318             16108              309
# 4                4.11            116619              8141              384
# ..                ...               ...               ...              ...
# 294              4.23               981               155              304
# 295              3.71               517                71              304
# 296              3.83              1200               247              304
# 297              3.72               600               164              326
# 298              3.76               658               120              256
#
#             Edition First Published date Kindle Version and Price  \
# 0         Hardcover            25-May-23            Kindle $14.99
# 1    Kindle Edition            14-Mar-23             Kindle $2.99
# 2         Hardcover            30-May-23             Kindle $2.99
# 3         Hardcover             1-Aug-23            Kindle $15.99
# 4         Hardcover            13-Jun-23            Kindle $14.99
# ..              ...                  ...                      ...
# 294       Hardcover            19-Sep-23            Kindle $14.99
# 295       Hardcover            19-Sep-23            Kindle $14.99
# 296       Paperback            18-Apr-23             Kindle $9.99
# 297       Hardcover            11-Apr-23            Kindle $14.43
# 298       Hardcover            18-Apr-23            Kindle $14.99
#
#      Kindle Price
# 0           14.99
# 1            2.99
# 2            2.99
# 3           15.99
# 4           14.99
# ..            ...
# 294         14.99
# 295         14.99
# 296          9.99
# 297         14.43
# 298         14.99
#
# [299 rows x 12 columns]>

# %%
df.dtypes
# Out:
# Readers Choice Votes          int64
# Readers Choice Category      object
# Title                        object
# Author                       object
# Total Avg Rating            float64
# Number of Ratings            object
# Number of Reviews            object
# Number of Pages               int64
# Edition                      object
# First Published date         object
# Kindle Version and Price     object
# Kindle Price                float64
# dtype: object

# %%
#Convert the rest of the columns to correct data types
convert_dict = {'Readers Choice Votes': 'int32',
                'Readers Choice Category': 'category',
                'Title': 'string',
                'Author': 'string',
                'Total Avg Rating': 'float16',
                'Number of Pages': 'int16',
                'Edition': 'category',
                'First Published date': 'datetime64[ns]',
                'Kindle Price': 'float16'}
df = df.astype(convert_dict)

# %%
df.dtypes
# Out:
# Readers Choice Votes                 int32
# Readers Choice Category           category
# Title                       string[python]
# Author                      string[python]
# Total Avg Rating                   float16
# Number of Ratings                   object
# Number of Reviews                   object
# Number of Pages                      int16
# Edition                           category
# First Published date        datetime64[ns]
# Kindle Version and Price            object
# Kindle Price                       float16
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Readers Choice Votes      299 non-null    int32
#  1   Readers Choice Category   299 non-null    category
#  2   Title                     299 non-null    string
#  3   Author                    299 non-null    string
#  4   Total Avg Rating          299 non-null    float16
#  5   Number of Ratings         299 non-null    object
#  6   Number of Reviews         299 non-null    object
#  7   Number of Pages           299 non-null    int16
#  8   Edition                   299 non-null    category
#  9   First Published date      299 non-null    datetime64[ns]
#  10  Kindle Version and Price  299 non-null    object
#  11  Kindle Price              299 non-null    float16
# dtypes: category(2), datetime64[ns](1), float16(2), int16(1), int32(1), object(3), string(2)
# memory usage: 18.5+ KB

# %%
df.describe()
# Out:
#        Readers Choice Votes  Total Avg Rating  Number of Pages  \
# count            299.000000        299.000000       299.000000
# mean           19662.919732          4.062500       392.394649
# min              935.000000          3.519531       192.000000
# 25%             3591.000000          3.854492       320.000000
# 50%            10099.000000          4.058594       368.000000
# 75%            24714.000000          4.250000       432.000000
# max           397565.000000          4.750000      1242.000000
# std            32406.337679          0.252197       123.698044
#
#                 First Published date  Kindle Price
# count                            299    299.000000
# mean   2023-05-19 09:57:11.438127104     11.328125
# min              2019-11-27 00:00:00      0.000000
# 25%              2023-02-28 12:00:00      9.992188
# 50%              2023-05-16 00:00:00     13.992188
# 75%              2023-08-29 00:00:00     14.992188
# max              2023-11-13 00:00:00     17.984375
# std                              NaN      5.351562

# %%
#visualization

cato_count = df['Readers Choice Category'].value_counts()
print(cato_count)
plt.figure(figsize=(12,6))
sns.barplot(x=cato_count.index,y=cato_count.values ,palette='Blues_d')
plt.xlabel('Distribution of books across categories')
plt.ylabel('Category')
plt.xticks(rotation=30,ha='right')
plt.show()
# Out:
# Readers Choice Category
# Fantasy                                  20
# Fiction                                  20
# Historical Fiction                       20
# Horror                                   20
# History & Biography                      20
# Humor                                    20
# Memoir & Autobiography                   20
# Romantasy                                20
# Mystery & Thriller                       20
# Nonfiction                               20
# Romance                                  20
# Young Adult Fantasy & Science Fiction    20
# Science Fiction                          20
# Young Adult Fiction                      20
# Debut Novel                              19
# Name: count, dtype: int64
# C:\Users\rites\AppData\Local\Temp\ipykernel_21572\3183570835.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cato_count.index,y=cato_count.values ,palette='Blues_d')

# %%
fig, axes = plt.subplots(3, 2, figsize=(16, 18), sharey=False, sharex=True)

# First plot Distributions of Readers Choice Votes
sns.boxplot(data=df, x='Readers Choice Category', y='Readers Choice Votes', palette='Set3', ax=axes[0, 0])
axes[0, 0].set_title('Distribution of Readers Choice Votes for Each Category')
axes[0, 0].set_ylabel('Votes')

# Second plot Distribution of Average Ratings
sns.boxplot(data=df, x='Readers Choice Category', y='Total Avg Rating', palette='Set3', ax=axes[0, 1])
axes[0, 1].set_title('Distribution of Average Ratings for Each Category')
axes[0, 1].set_ylabel('Avg Ratings')

# Third plot Distribution of Number of Ratings
sns.boxplot(data=df, x='Readers Choice Category', y='Number of Ratings', palette='Set3', ax=axes[1, 0])
axes[1, 0].set_title('Distribution of Number of Ratings for Each Category')
axes[1, 0].set_ylabel('Ratings')

# Fourth plot Distribution of Number of Reviews
sns.boxplot(data=df, x='Readers Choice Category', y='Number of Reviews', palette='Set3', ax=axes[1, 1])
axes[1, 1].set_title('Distribution of Number of Reviews for Each Category')
axes[1, 1].set_ylabel('Reviews')

# Fifth plot Distribution of Number of Pages
sns.boxplot(data=df, x='Readers Choice Category', y='Number of Pages', palette='Set3', ax=axes[2, 0])
axes[2, 0].set_title('Distribution of Number of Pages for Each Category')
axes[2, 0].set_ylabel('Pages')

# Sixth plot Distribution of Kindle Price
sns.boxplot(data=df, x='Readers Choice Category', y='Kindle Price', palette='Set3', ax=axes[2, 1])
axes[2, 1].set_title('Distribution of Kindle Price ($) for Each Category')
axes[2, 1].set_ylabel('Kindle Price ($)')

for ax in axes[2, :]:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='right')
    
fig.tight_layout()
plt.show()
# Out:
# C:\Users\rites\AppData\Local\Temp\ipykernel_21572\1939750937.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Readers Choice Category', y='Readers Choice Votes', palette='Set3', ax=axes[0, 0])
# C:\Users\rites\AppData\Local\Temp\ipykernel_21572\1939750937.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Readers Choice Category', y='Total Avg Rating', palette='Set3', ax=axes[0, 1])
# C:\Users\rites\AppData\Local\Temp\ipykernel_21572\1939750937.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Readers Choice Category', y='Number of Ratings', palette='Set3', ax=axes[1, 0])
# C:\Users\rites\AppData\Local\Temp\ipykernel_21572\1939750937.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Readers Choice Category', y='Number of Reviews', palette='Set3', ax=axes[1, 1])
# C:\Users\rites\AppData\Local\Temp\ipykernel_21572\1939750937.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Readers Choice Category', y='Number of Pages', palette='Set3', ax=axes[2, 0])
# C:\Users\rites\AppData\Local\Temp\ipykernel_21572\1939750937.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Readers Choice Category', y='Kindle Price', palette='Set3', ax=axes[2, 1])
# C:\Users\rites\AppData\Local\Temp\ipykernel_21572\1939750937.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='right')
# C:\Users\rites\AppData\Local\Temp\ipykernel_21572\1939750937.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='right')
