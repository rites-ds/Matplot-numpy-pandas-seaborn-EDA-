# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
np.random.seed(45)

# %%
df = pd.DataFrame({
    'Age': np.random.randint(18, 60, 100),
    'Salary': np.random.randint(25000, 120000, 100),
    'Department': np.random.choice(['HR', 'Finance', 'IT', 'Marketing'], 100),
    'Experience': np.random.randint(1, 20, 100),
    'Gender': np.random.choice(['Male', 'Female'], 100)
})

# %%
df
# Out:
#     Age  Salary Department  Experience  Gender
# 0    26   45027         IT          15  Female
# 1    53  111828    Finance           1  Female
# 2    58   63093  Marketing          19  Female
# 3    34   67941         HR           9  Female
# 4    53   76791    Finance           3    Male
# ..  ...     ...        ...         ...     ...
# 95   29   92409    Finance           6  Female
# 96   39  105600  Marketing           9  Female
# 97   51   81578  Marketing          14  Female
# 98   56   60183         IT          16  Female
# 99   46   89119         IT           5  Female
#
# [100 rows x 5 columns]

# %%
df.shape  # (Rows, Columns)
# Out:
# (100, 5)

# %%
df.head  # Show first 5 rows
# Out:
# <bound method NDFrame.head of     Age  Salary Department  Experience  Gender
# 0    26   45027         IT          15  Female
# 1    53  111828    Finance           1  Female
# 2    58   63093  Marketing          19  Female
# 3    34   67941         HR           9  Female
# 4    53   76791    Finance           3    Male
# ..  ...     ...        ...         ...     ...
# 95   29   92409    Finance           6  Female
# 96   39  105600  Marketing           9  Female
# 97   51   81578  Marketing          14  Female
# 98   56   60183         IT          16  Female
# 99   46   89119         IT           5  Female
#
# [100 rows x 5 columns]>

# %%
df.dtypes # check data type of each column
# Out:
# Age            int32
# Salary         int32
# Department    object
# Experience     int32
# Gender        object
# dtype: object

# %%
df.isnull().sum()  # Count of missing/null values
# Out:
# Age           0
# Salary        0
# Department    0
# Experience    0
# Gender        0
# dtype: int64

# %%
print("\nSummary Statistics:\n", df.describe())  # Numerical summary (mean, min, max, etc.)
# Out:
# Summary Statistics:
#                Age         Salary  Experience
# count  100.000000     100.000000   100.00000
# mean    39.530000   73421.360000    10.81000
# std     11.959912   28009.719105     5.27371
# min     18.000000   28131.000000     1.00000
# 25%     28.750000   45804.000000     6.75000
# 50%     40.000000   74159.500000    11.00000
# 75%     50.250000   97388.500000    15.25000
# max     59.000000  119162.000000    19.00000

# %%
plt.figure(figsize=(12,5))

# %%
# Histogram for Age
plt.subplot(1, 2, 1)  # Create subplot (row 1, col 2, position 1)
plt.hist(df['Age'], bins=10, color='skyblue', edgecolor='black')
plt.title('Age Distribution')  # Chart title
plt.xlabel('Age')  # X-axis label
plt.ylabel('Frequency')  # Y-axis label
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Histogram for Salary
plt.subplot(1, 2, 2)  # Position 2
plt.hist(df['Salary'], bins=10, color='lightgreen', edgecolor='black')
plt.title('Salary Distribution')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.tight_layout()  # Adjust layout to avoid overlapping
plt.show()

# %%
plt.figure(figsize=(12, 4))

# Bar chart for Department
plt.subplot(1, 2, 1)
df['Department'].value_counts().plot(kind='bar', color='orange', edgecolor='black')
plt.title('Department Count')
plt.xlabel('Department')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Bar chart for Gender
plt.subplot(1, 2, 2)
df['Gender'].value_counts().plot(kind='bar', color='pink', edgecolor='black')
plt.title('Gender Count')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
# Scatter Plot: Age vs Salary
plt.figure(figsize=(10, 5))
plt.scatter(df['Age'], df['Salary'], color='purple', alpha=0.6)  # alpha=transparency
plt.title('Age vs Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %%
# Box Plot: Salary distribution per Department
plt.figure(figsize=(8, 5))
df.boxplot(column='Salary', by='Department', grid=False)
plt.title('Salary by Department')
plt.suptitle('')  # Remove default title
plt.ylabel('Salary')
plt.show()

# %%
plt.figure(figsize=(6, 4))
corr = df[['Age', 'Salary', 'Experience']].corr()  # Calculate correlation
plt.matshow(corr, cmap='coolwarm', fignum=1)  # Color heatmap
plt.colorbar()  # Add color scale bar
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)  # X labels
plt.yticks(range(len(corr.columns)), corr.columns)  # Y labels
plt.title('Correlation Matrix', pad=20)
plt.show()
